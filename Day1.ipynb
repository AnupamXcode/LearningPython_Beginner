# %% [markdown]
# <a href="https://colab.research.google.com/github/AnupamXcode/-TF-Vanill-javacript-ui-components/blob/main/Learning_Google_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Day 1: Leaning Coading

# %%
print("Hey Anupam How's Youuu")
# Out:
# Hey Anupam How's Youuu

# %%
print("Hello Anupam");print("You are a Great,");print("Coder")
# Out:
# Hello Anupam
# You are a Great,
# Coder

# %%
# using end="" parameter
# we add a space after end=" " for better readability.

print("Hello Anupam",end="");print(":-Human and a Bright Student")
# Out:
# Hello Anupam:-Human and a Bright Student

# %%
print("I am ",20,"Years old Now")
# Out:
# I am  20 Years old Now

# %%
# Variables in Python
x = 5
y = "John"
print(x)
print(y)

# printing the Type of Variable
x = 5
y = "John"
print(type(x))
print(type(y))
# Out:
# 5
# John
# <class 'int'>
# <class 'str'>

# %%
# Many Values to Multiple Variables
x, y, z = "Orange", "Banana", "Cherry"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry

# %%
x=y=z="Anupam"
print(x)
print(z)
# Out:
# Anupam
# Anupam

# %%
friends=["Alex","Sopia","Steve"]
x,y,z=friends
print(x,end=" and ");print(y,"are Lovers whereas "),print(z,"is Steve")
# Out:
# Alex and Sopia are Lovers whereas
# Steve is Steve
# (None, None)

# %%
x="Anupam"
y="is in"
z="Learning Phase"
print(x,y,z)
print(x+y+z)
print(x.upper())
# Out:
# Anupam is in Learning Phase
# Anupamis inLearning Phase
# ANUPAM

# %%
x=float(2.8)
print(x)
print(type(x))
# Out:
# 2.8
# <class 'float'>

# %%
# Getting the random value
import random
print(random.randrange(1, 10))
# Out:
# 8
